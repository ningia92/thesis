# %%
from tensorflow import keras
from tensorflow.keras import layers

from matplotlib import pyplot as plt
import tensorflow as tf
import numpy as np
import time

physical_devices = tf.config.list_physical_devices('GPU') 
#for device in physical_devices:
#    tf.config.experimental.set_memory_growth(device, True)
    
#mirrored_strategy = tf.distribute.MirroredStrategy(cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

print("Num GPUs Available: ", len(physical_devices))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# ## Classifing data with ResNet50

# %% [markdown]
# ### Create dataset

# %%
img_size = 64
num_classes = 2

dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "similarity",
    image_size=(img_size,img_size),
    batch_size=256,
    label_mode='binary',
)
# Out:
# Found 24894 files belonging to 2 classes.

# %%
def get_dataset_partitions(ds, ds_size, train_split=0.7, val_split=0.1, test_split=0.2, shuffle=True, shuffle_size=10000): 
    if shuffle:
        # Specify seed to always have the same split distribution between runs
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    test_size = int(test_split * ds_size)
    
    train_ds = ds.take(train_size)    
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(test_size)
    
    return train_ds, val_ds, test_ds

# %%
ds_size=tf.data.experimental.cardinality(dataset).numpy()

train_ds, val_ds, test_ds = get_dataset_partitions(dataset, ds_size)

train_ds = train_ds.map(lambda x, y: (tf.keras.applications.resnet.preprocess_input(x), y))
val_ds = val_ds.map(lambda x, y: (tf.keras.applications.resnet.preprocess_input(x), y))
test_ds = test_ds.map(lambda x, y: (tf.keras.applications.resnet.preprocess_input(x), y))

print(tf.data.experimental.cardinality(train_ds).numpy())
print(tf.data.experimental.cardinality(val_ds).numpy())
print(tf.data.experimental.cardinality(test_ds).numpy())
# Out:
# 68
# 9
# 11

# %%
from tensorflow import keras

resNet=tf.keras.applications.ResNet152(
    include_top=False,
    weights='imagenet',
    input_shape=(img_size,img_size,3),
)

model = keras.Sequential()
model.add(resNet)
model.add(layers.Flatten())
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet152 (Functional)       (None, 2, 2, 2048)        58370944
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 8193
# =================================================================
# Total params: 58,379,137
# Trainable params: 58,227,713
# Non-trainable params: 151,424
# _________________________________________________________________

# %%
from tensorflow.keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
#model.load_weights('best_resnet.h5')

# %%
tic = time.time()

#with mirrored_strategy.scope():
model.compile(optimizer=keras.optimizers.Adam(), loss='binary_crossentropy', metrics=['acc', 'Precision', 'Recall', 'AUC', f1_m])
    
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
'''
best_resnet = tf.keras.callbacks.ModelCheckpoint(
                                          filepath='best_resnet.h5',
                                          save_weights_only=False,
                                          monitor='val_acc',
                                          mode='max',
                                          save_best_only=True)
'''

history = model.fit(train_ds, epochs=100, validation_data=val_ds, callbacks=[early_stopping, reduce_lr])

print("Training time:", time.strftime("%H:%M:%S", time.gmtime(time.time() - tic)))
# Out:
# Epoch 1/100
# 68/68 [==============================] - 103s 593ms/step - loss: 0.4740 - acc: 0.9392 - precision: 0.9391 - recall: 0.9392 - auc: 0.9780 - f1_m: 0.9390 - val_loss: 7308367626240.0000 - val_acc: 0.4874 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_f1_m: 0.0000e+00
# Epoch 2/100
# 68/68 [==============================] - 49s 523ms/step - loss: 0.1576 - acc: 0.9886 - precision: 0.9868 - recall: 0.9903 - auc: 0.9962 - f1_m: 0.9883 - val_loss: 5.5409 - val_acc: 0.5490 - val_precision: 1.0000 - val_recall: 0.1097 - val_auc: 0.6971 - val_f1_m: 0.1972
# Epoch 3/100
# 68/68 [==============================] - 48s 523ms/step - loss: 0.1577 - acc: 0.9751 - precision: 0.9735 - recall: 0.9768 - auc: 0.9947 - f1_m: 0.9743 - val_loss: 3669460480.0000 - val_acc: 0.5035 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4996 - val_f1_m: 0.0000e+00
# Epoch 4/100
# 68/68 [==============================] - 49s 529ms/step - loss: 0.0482 - acc: 0.9841 - precision: 0.9813 - recall: 0.9870 - auc: 0.9981 - f1_m: 0.9838 - val_loss: 239.8062 - val_acc: 0.7973 - val_precision: 0.9972 - val_recall: 0.6066 - val_auc: 0.9111 - val_f1_m: 0.7547
# Epoch 5/100
# 68/68 [==============================] - 48s 523ms/step - loss: 0.0138 - acc: 0.9948 - precision: 0.9941 - recall: 0.9955 - auc: 0.9997 - f1_m: 0.9949 - val_loss: 0.0161 - val_acc: 0.9944 - val_precision: 0.9991 - val_recall: 0.9898 - val_auc: 1.0000 - val_f1_m: 0.9945
# Epoch 6/100
# 68/68 [==============================] - 48s 527ms/step - loss: 0.0103 - acc: 0.9964 - precision: 0.9969 - recall: 0.9959 - auc: 0.9998 - f1_m: 0.9964 - val_loss: 0.0348 - val_acc: 0.9896 - val_precision: 0.9863 - val_recall: 0.9931 - val_auc: 0.9992 - val_f1_m: 0.9897
# Epoch 7/100
# 68/68 [==============================] - 49s 532ms/step - loss: 0.0065 - acc: 0.9980 - precision: 0.9979 - recall: 0.9981 - auc: 0.9999 - f1_m: 0.9980 - val_loss: 0.0103 - val_acc: 0.9961 - val_precision: 0.9956 - val_recall: 0.9965 - val_auc: 0.9999 - val_f1_m: 0.9960
# Epoch 8/100
# 68/68 [==============================] - 48s 526ms/step - loss: 0.0039 - acc: 0.9987 - precision: 0.9990 - recall: 0.9985 - auc: 1.0000 - f1_m: 0.9987 - val_loss: 0.0035 - val_acc: 0.9991 - val_precision: 0.9983 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 0.9992
# Epoch 9/100
# 68/68 [==============================] - 48s 525ms/step - loss: 0.0028 - acc: 0.9990 - precision: 0.9990 - recall: 0.9990 - auc: 1.0000 - f1_m: 0.9990 - val_loss: 0.0476 - val_acc: 0.9844 - val_precision: 0.9700 - val_recall: 1.0000 - val_auc: 0.9980 - val_f1_m: 0.9827
# Epoch 10/100
# 68/68 [==============================] - 48s 526ms/step - loss: 0.0027 - acc: 0.9991 - precision: 0.9993 - recall: 0.9990 - auc: 0.9999 - f1_m: 0.9991 - val_loss: 0.0087 - val_acc: 0.9965 - val_precision: 0.9931 - val_recall: 1.0000 - val_auc: 0.9996 - val_f1_m: 0.9965
# Epoch 11/100
# 68/68 [==============================] - 48s 525ms/step - loss: 0.0042 - acc: 0.9987 - precision: 0.9985 - recall: 0.9988 - auc: 0.9999 - f1_m: 0.9987 - val_loss: 0.0016 - val_acc: 0.9991 - val_precision: 0.9991 - val_recall: 0.9991 - val_auc: 1.0000 - val_f1_m: 0.9992
# Epoch 12/100
# 68/68 [==============================] - 48s 526ms/step - loss: 0.0020 - acc: 0.9994 - precision: 0.9997 - recall: 0.9992 - auc: 1.0000 - f1_m: 0.9994 - val_loss: 0.0117 - val_acc: 0.9957 - val_precision: 0.9917 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 0.9958
# Epoch 13/100
# 68/68 [==============================] - 48s 526ms/step - loss: 9.7732e-04 - acc: 0.9995 - precision: 0.9995 - recall: 0.9995 - auc: 1.0000 - f1_m: 0.9995 - val_loss: 1.5544e-04 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 14/100
# 68/68 [==============================] - 48s 520ms/step - loss: 0.0044 - acc: 0.9985 - precision: 0.9983 - recall: 0.9988 - auc: 0.9999 - f1_m: 0.9984 - val_loss: 0.1052 - val_acc: 0.9809 - val_precision: 0.9633 - val_recall: 1.0000 - val_auc: 0.9916 - val_f1_m: 0.9811
# Epoch 15/100
# 68/68 [==============================] - 48s 526ms/step - loss: 0.0155 - acc: 0.9952 - precision: 0.9945 - recall: 0.9961 - auc: 0.9996 - f1_m: 0.9950 - val_loss: 673.6875 - val_acc: 0.9575 - val_precision: 0.9779 - val_recall: 0.9350 - val_auc: 0.9649 - val_f1_m: 0.9557
# Epoch 16/100
# 68/68 [==============================] - 48s 526ms/step - loss: 0.0051 - acc: 0.9983 - precision: 0.9983 - recall: 0.9984 - auc: 1.0000 - f1_m: 0.9984 - val_loss: 0.0142 - val_acc: 0.9939 - val_precision: 0.9886 - val_recall: 1.0000 - val_auc: 0.9995 - val_f1_m: 0.9942
# Epoch 17/100
# 68/68 [==============================] - 48s 523ms/step - loss: 0.0064 - acc: 0.9983 - precision: 0.9986 - recall: 0.9979 - auc: 0.9999 - f1_m: 0.9981 - val_loss: 0.0295 - val_acc: 0.9870 - val_precision: 1.0000 - val_recall: 0.9745 - val_auc: 0.9999 - val_f1_m: 0.9870
# Epoch 18/100
# 68/68 [==============================] - 48s 522ms/step - loss: 0.0028 - acc: 0.9990 - precision: 0.9988 - recall: 0.9992 - auc: 1.0000 - f1_m: 0.9988 - val_loss: 0.0061 - val_acc: 0.9986 - val_precision: 1.0000 - val_recall: 0.9971 - val_auc: 0.9995 - val_f1_m: 0.9986
# Epoch 19/100
# 68/68 [==============================] - 48s 523ms/step - loss: 0.0584 - acc: 0.9822 - precision: 0.9763 - recall: 0.9882 - auc: 0.9975 - f1_m: 0.9823 - val_loss: 644395.6250 - val_acc: 0.5039 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4983 - val_f1_m: 0.0000e+00
# Epoch 20/100
# 68/68 [==============================] - 48s 523ms/step - loss: 0.0282 - acc: 0.9912 - precision: 0.9891 - recall: 0.9934 - auc: 0.9992 - f1_m: 0.9913 - val_loss: 19.6019 - val_acc: 0.7509 - val_precision: 0.6913 - val_recall: 0.9389 - val_auc: 0.7878 - val_f1_m: 0.7960
# Epoch 21/100
# 68/68 [==============================] - 48s 526ms/step - loss: 0.0115 - acc: 0.9960 - precision: 0.9944 - recall: 0.9976 - auc: 0.9999 - f1_m: 0.9960 - val_loss: 1.7881 - val_acc: 0.7817 - val_precision: 0.6948 - val_recall: 1.0000 - val_auc: 0.8554 - val_f1_m: 0.8195
# Epoch 22/100
# 68/68 [==============================] - 48s 520ms/step - loss: 0.0132 - acc: 0.9943 - precision: 0.9940 - recall: 0.9947 - auc: 0.9999 - f1_m: 0.9940 - val_loss: 0.0636 - val_acc: 0.9805 - val_precision: 0.9652 - val_recall: 0.9965 - val_auc: 0.9976 - val_f1_m: 0.9805
# Epoch 23/100
# 68/68 [==============================] - 48s 523ms/step - loss: 0.0062 - acc: 0.9973 - precision: 0.9963 - recall: 0.9984 - auc: 1.0000 - f1_m: 0.9972 - val_loss: 0.0245 - val_acc: 0.9918 - val_precision: 0.9840 - val_recall: 1.0000 - val_auc: 0.9995 - val_f1_m: 0.9917
# Epoch 24/100
# 68/68 [==============================] - 48s 519ms/step - loss: 0.0065 - acc: 0.9980 - precision: 0.9980 - recall: 0.9980 - auc: 0.9999 - f1_m: 0.9980 - val_loss: 0.0026 - val_acc: 0.9986 - val_precision: 0.9991 - val_recall: 0.9981 - val_auc: 1.0000 - val_f1_m: 0.9987
# Epoch 25/100
# 68/68 [==============================] - 48s 523ms/step - loss: 0.0039 - acc: 0.9988 - precision: 0.9990 - recall: 0.9987 - auc: 0.9999 - f1_m: 0.9987 - val_loss: 0.0103 - val_acc: 0.9939 - val_precision: 0.9890 - val_recall: 0.9991 - val_auc: 1.0000 - val_f1_m: 0.9940
# Epoch 26/100
# 68/68 [==============================] - 48s 526ms/step - loss: 0.0030 - acc: 0.9991 - precision: 0.9991 - recall: 0.9991 - auc: 1.0000 - f1_m: 0.9991 - val_loss: 0.0010 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 27/100
# 68/68 [==============================] - 48s 522ms/step - loss: 0.0041 - acc: 0.9984 - precision: 0.9985 - recall: 0.9983 - auc: 1.0000 - f1_m: 0.9982 - val_loss: 0.0019 - val_acc: 0.9991 - val_precision: 0.9983 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 0.9992
# Epoch 28/100
# 68/68 [==============================] - 48s 523ms/step - loss: 0.0012 - acc: 0.9997 - precision: 0.9998 - recall: 0.9997 - auc: 1.0000 - f1_m: 0.9997 - val_loss: 0.0028 - val_acc: 0.9991 - val_precision: 0.9983 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 0.9992
# Epoch 29/100
# 68/68 [==============================] - 48s 523ms/step - loss: 0.0015 - acc: 0.9997 - precision: 0.9997 - recall: 0.9997 - auc: 1.0000 - f1_m: 0.9996 - val_loss: 0.0025 - val_acc: 0.9991 - val_precision: 1.0000 - val_recall: 0.9983 - val_auc: 1.0000 - val_f1_m: 0.9992
# Epoch 30/100
# 68/68 [==============================] - 48s 523ms/step - loss: 0.0048 - acc: 0.9983 - precision: 0.9986 - recall: 0.9980 - auc: 0.9999 - f1_m: 0.9983 - val_loss: 0.0071 - val_acc: 0.9978 - val_precision: 1.0000 - val_recall: 0.9958 - val_auc: 0.9996 - val_f1_m: 0.9979
# Epoch 31/100
# 68/68 [==============================] - 48s 527ms/step - loss: 0.0038 - acc: 0.9989 - precision: 0.9986 - recall: 0.9991 - auc: 0.9999 - f1_m: 0.9988 - val_loss: 0.0013 - val_acc: 0.9996 - val_precision: 0.9991 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 0.9996
# Epoch 32/100
# 68/68 [==============================] - 48s 526ms/step - loss: 9.0279e-04 - acc: 0.9998 - precision: 0.9999 - recall: 0.9997 - auc: 1.0000 - f1_m: 0.9998 - val_loss: 0.0012 - val_acc: 0.9995 - val_precision: 1.0000 - val_recall: 0.9990 - val_auc: 1.0000 - val_f1_m: 0.9996
# Epoch 33/100
# 68/68 [==============================] - 48s 523ms/step - loss: 9.7299e-04 - acc: 0.9997 - precision: 0.9995 - recall: 0.9999 - auc: 1.0000 - f1_m: 0.9997 - val_loss: 0.0039 - val_acc: 0.9983 - val_precision: 0.9974 - val_recall: 0.9991 - val_auc: 1.0000 - val_f1_m: 0.9983
# Epoch 34/100
# 68/68 [==============================] - 48s 523ms/step - loss: 7.9089e-04 - acc: 0.9998 - precision: 0.9999 - recall: 0.9997 - auc: 1.0000 - f1_m: 0.9998 - val_loss: 0.0017 - val_acc: 0.9996 - val_precision: 0.9992 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 0.9996
# Epoch 35/100
# 68/68 [==============================] - 48s 523ms/step - loss: 0.0011 - acc: 0.9996 - precision: 0.9995 - recall: 0.9996 - auc: 1.0000 - f1_m: 0.9996 - val_loss: 3.5276e-04 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 36/100
# 68/68 [==============================] - 48s 523ms/step - loss: 5.0663e-04 - acc: 0.9998 - precision: 0.9999 - recall: 0.9998 - auc: 1.0000 - f1_m: 0.9998 - val_loss: 5.2628e-05 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 37/100
# 68/68 [==============================] - 48s 530ms/step - loss: 6.7467e-04 - acc: 0.9998 - precision: 0.9999 - recall: 0.9998 - auc: 1.0000 - f1_m: 0.9998 - val_loss: 2.5665e-04 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 38/100
# 68/68 [==============================] - 48s 523ms/step - loss: 8.5568e-04 - acc: 0.9998 - precision: 0.9999 - recall: 0.9997 - auc: 1.0000 - f1_m: 0.9998 - val_loss: 0.0010 - val_acc: 0.9996 - val_precision: 1.0000 - val_recall: 0.9991 - val_auc: 1.0000 - val_f1_m: 0.9996
# Epoch 39/100
# 68/68 [==============================] - 48s 529ms/step - loss: 6.3386e-04 - acc: 0.9998 - precision: 0.9999 - recall: 0.9998 - auc: 1.0000 - f1_m: 0.9998 - val_loss: 1.2904e-04 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 40/100
# 68/68 [==============================] - 49s 532ms/step - loss: 6.4199e-04 - acc: 0.9998 - precision: 0.9999 - recall: 0.9997 - auc: 1.0000 - f1_m: 0.9998 - val_loss: 0.0013 - val_acc: 0.9996 - val_precision: 1.0000 - val_recall: 0.9991 - val_auc: 1.0000 - val_f1_m: 0.9996
# Epoch 41/100
# 68/68 [==============================] - 48s 527ms/step - loss: 4.2261e-04 - acc: 0.9998 - precision: 0.9999 - recall: 0.9998 - auc: 1.0000 - f1_m: 0.9998 - val_loss: 1.1028e-04 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 42/100
# 68/68 [==============================] - 48s 524ms/step - loss: 7.7101e-04 - acc: 0.9998 - precision: 0.9999 - recall: 0.9997 - auc: 1.0000 - f1_m: 0.9998 - val_loss: 8.2044e-04 - val_acc: 0.9996 - val_precision: 1.0000 - val_recall: 0.9992 - val_auc: 1.0000 - val_f1_m: 0.9996
# Epoch 43/100
# 68/68 [==============================] - 48s 526ms/step - loss: 6.6110e-04 - acc: 0.9997 - precision: 0.9998 - recall: 0.9997 - auc: 1.0000 - f1_m: 0.9997 - val_loss: 0.0017 - val_acc: 0.9996 - val_precision: 1.0000 - val_recall: 0.9991 - val_auc: 1.0000 - val_f1_m: 0.9996
# Epoch 44/100
# 68/68 [==============================] - 48s 529ms/step - loss: 5.9884e-04 - acc: 0.9998 - precision: 1.0000 - recall: 0.9997 - auc: 1.0000 - f1_m: 0.9998 - val_loss: 8.8653e-04 - val_acc: 0.9991 - val_precision: 1.0000 - val_recall: 0.9983 - val_auc: 1.0000 - val_f1_m: 0.9991
# Epoch 45/100
# 68/68 [==============================] - 48s 526ms/step - loss: 1.8895e-04 - acc: 0.9999 - precision: 1.0000 - recall: 0.9999 - auc: 1.0000 - f1_m: 0.9999 - val_loss: 2.7375e-05 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 46/100
# 68/68 [==============================] - 48s 526ms/step - loss: 1.2345e-04 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 1.5277e-05 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 47/100
# 68/68 [==============================] - 48s 522ms/step - loss: 6.1076e-04 - acc: 0.9998 - precision: 0.9999 - recall: 0.9998 - auc: 1.0000 - f1_m: 0.9998 - val_loss: 0.0011 - val_acc: 0.9995 - val_precision: 1.0000 - val_recall: 0.9990 - val_auc: 1.0000 - val_f1_m: 0.9996
# Epoch 48/100
# 68/68 [==============================] - 48s 526ms/step - loss: 3.2436e-04 - acc: 0.9999 - precision: 0.9998 - recall: 1.0000 - auc: 1.0000 - f1_m: 0.9999 - val_loss: 0.1897 - val_acc: 0.9431 - val_precision: 0.8944 - val_recall: 1.0000 - val_auc: 0.9933 - val_f1_m: 0.9444
# Epoch 49/100
# 68/68 [==============================] - 48s 523ms/step - loss: 0.0051 - acc: 0.9984 - precision: 0.9985 - recall: 0.9984 - auc: 0.9999 - f1_m: 0.9985 - val_loss: 7.3586e-04 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 50/100
# 68/68 [==============================] - 48s 524ms/step - loss: 0.0011 - acc: 0.9998 - precision: 0.9999 - recall: 0.9997 - auc: 1.0000 - f1_m: 0.9998 - val_loss: 3.3158e-04 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 51/100
# 68/68 [==============================] - 48s 523ms/step - loss: 6.2895e-04 - acc: 0.9997 - precision: 0.9998 - recall: 0.9997 - auc: 1.0000 - f1_m: 0.9997 - val_loss: 0.0022 - val_acc: 0.9991 - val_precision: 0.9983 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 0.9992
# Epoch 52/100
# 68/68 [==============================] - 48s 520ms/step - loss: 0.0032 - acc: 0.9990 - precision: 0.9988 - recall: 0.9992 - auc: 0.9999 - f1_m: 0.9990 - val_loss: 0.2473 - val_acc: 0.9401 - val_precision: 1.0000 - val_recall: 0.8802 - val_auc: 0.9852 - val_f1_m: 0.9363
# Epoch 53/100
# 68/68 [==============================] - 48s 523ms/step - loss: 0.0020 - acc: 0.9993 - precision: 0.9993 - recall: 0.9993 - auc: 1.0000 - f1_m: 0.9992 - val_loss: 1.4215e-04 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 54/100
# 68/68 [==============================] - 48s 521ms/step - loss: 0.0032 - acc: 0.9991 - precision: 0.9992 - recall: 0.9991 - auc: 0.9999 - f1_m: 0.9991 - val_loss: 0.0012 - val_acc: 0.9996 - val_precision: 0.9991 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 0.9996
# Epoch 55/100
# 68/68 [==============================] - 48s 523ms/step - loss: 0.0011 - acc: 0.9998 - precision: 0.9999 - recall: 0.9997 - auc: 1.0000 - f1_m: 0.9998 - val_loss: 2.8896e-04 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 56/100
# 68/68 [==============================] - 48s 523ms/step - loss: 0.0011 - acc: 0.9996 - precision: 0.9997 - recall: 0.9995 - auc: 1.0000 - f1_m: 0.9996 - val_loss: 2.2722e-04 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 57/100
# 68/68 [==============================] - 48s 526ms/step - loss: 3.9214e-04 - acc: 0.9999 - precision: 1.0000 - recall: 0.9999 - auc: 1.0000 - f1_m: 0.9999 - val_loss: 0.0135 - val_acc: 0.9974 - val_precision: 0.9948 - val_recall: 1.0000 - val_auc: 0.9987 - val_f1_m: 0.9975
# Epoch 58/100
# 68/68 [==============================] - 48s 526ms/step - loss: 0.0013 - acc: 0.9997 - precision: 0.9997 - recall: 0.9997 - auc: 0.9999 - f1_m: 0.9997 - val_loss: 6.8139e-04 - val_acc: 0.9995 - val_precision: 1.0000 - val_recall: 0.9991 - val_auc: 1.0000 - val_f1_m: 0.9996
# Epoch 59/100
# 68/68 [==============================] - 48s 523ms/step - loss: 1.9684e-04 - acc: 0.9999 - precision: 1.0000 - recall: 0.9999 - auc: 1.0000 - f1_m: 0.9999 - val_loss: 9.3793e-05 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 60/100
# 68/68 [==============================] - 48s 523ms/step - loss: 0.0038 - acc: 0.9987 - precision: 0.9987 - recall: 0.9987 - auc: 0.9998 - f1_m: 0.9988 - val_loss: 2.5109e-04 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 61/100
# 68/68 [==============================] - 48s 524ms/step - loss: 0.0020 - acc: 0.9994 - precision: 0.9995 - recall: 0.9993 - auc: 1.0000 - f1_m: 0.9994 - val_loss: 0.0352 - val_acc: 0.9870 - val_precision: 1.0000 - val_recall: 0.9746 - val_auc: 0.9996 - val_f1_m: 0.9870
# Epoch 62/100
# 68/68 [==============================] - 48s 523ms/step - loss: 0.0013 - acc: 0.9996 - precision: 0.9995 - recall: 0.9997 - auc: 1.0000 - f1_m: 0.9996 - val_loss: 2.6700e-04 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 63/100
# 68/68 [==============================] - 48s 523ms/step - loss: 3.5146e-04 - acc: 0.9998 - precision: 0.9999 - recall: 0.9998 - auc: 1.0000 - f1_m: 0.9998 - val_loss: 5.1464e-04 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 64/100
# 68/68 [==============================] - 48s 523ms/step - loss: 5.5134e-05 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 3.9819e-05 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 65/100
# 68/68 [==============================] - 48s 523ms/step - loss: 1.2476e-04 - acc: 0.9999 - precision: 1.0000 - recall: 0.9999 - auc: 1.0000 - f1_m: 0.9999 - val_loss: 7.1918e-06 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 66/100
# 68/68 [==============================] - 48s 525ms/step - loss: 0.0031 - acc: 0.9991 - precision: 0.9991 - recall: 0.9991 - auc: 0.9999 - f1_m: 0.9991 - val_loss: 0.0028 - val_acc: 0.9995 - val_precision: 1.0000 - val_recall: 0.9990 - val_auc: 0.9995 - val_f1_m: 0.9996
# Epoch 67/100
# 68/68 [==============================] - 48s 523ms/step - loss: 0.0029 - acc: 0.9991 - precision: 0.9992 - recall: 0.9991 - auc: 1.0000 - f1_m: 0.9992 - val_loss: 0.0016 - val_acc: 0.9991 - val_precision: 0.9983 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 0.9992
# Epoch 68/100
# 68/68 [==============================] - 48s 523ms/step - loss: 7.9195e-04 - acc: 0.9997 - precision: 0.9998 - recall: 0.9995 - auc: 1.0000 - f1_m: 0.9995 - val_loss: 1.1331e-04 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 69/100
# 68/68 [==============================] - 48s 523ms/step - loss: 2.4136e-04 - acc: 0.9999 - precision: 0.9999 - recall: 1.0000 - auc: 1.0000 - f1_m: 0.9999 - val_loss: 3.2297e-05 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 70/100
# 68/68 [==============================] - 48s 520ms/step - loss: 4.3178e-04 - acc: 0.9999 - precision: 0.9999 - recall: 0.9999 - auc: 1.0000 - f1_m: 0.9999 - val_loss: 1.8379e-05 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 71/100
# 68/68 [==============================] - 48s 520ms/step - loss: 0.0049 - acc: 0.9981 - precision: 0.9984 - recall: 0.9979 - auc: 0.9999 - f1_m: 0.9982 - val_loss: 0.0135 - val_acc: 0.9948 - val_precision: 0.9910 - val_recall: 0.9991 - val_auc: 0.9999 - val_f1_m: 0.9954
# Epoch 72/100
# 68/68 [==============================] - 48s 523ms/step - loss: 0.0017 - acc: 0.9996 - precision: 0.9994 - recall: 0.9998 - auc: 0.9999 - f1_m: 0.9996 - val_loss: 0.0020 - val_acc: 0.9996 - val_precision: 1.0000 - val_recall: 0.9991 - val_auc: 1.0000 - val_f1_m: 0.9995
# Epoch 73/100
# 68/68 [==============================] - 48s 523ms/step - loss: 0.0018 - acc: 0.9994 - precision: 0.9993 - recall: 0.9995 - auc: 1.0000 - f1_m: 0.9994 - val_loss: 0.3959 - val_acc: 0.9188 - val_precision: 0.8653 - val_recall: 0.9992 - val_auc: 0.9678 - val_f1_m: 0.9268
# Epoch 74/100
# 68/68 [==============================] - 48s 520ms/step - loss: 0.0022 - acc: 0.9993 - precision: 0.9994 - recall: 0.9992 - auc: 1.0000 - f1_m: 0.9993 - val_loss: 0.1785 - val_acc: 0.9657 - val_precision: 0.9372 - val_recall: 0.9983 - val_auc: 0.9860 - val_f1_m: 0.9663
# Epoch 75/100
# 68/68 [==============================] - 48s 517ms/step - loss: 9.8793e-04 - acc: 0.9996 - precision: 0.9997 - recall: 0.9995 - auc: 1.0000 - f1_m: 0.9996 - val_loss: 0.0017 - val_acc: 0.9991 - val_precision: 1.0000 - val_recall: 0.9983 - val_auc: 1.0000 - val_f1_m: 0.9991
# Epoch 76/100
# 68/68 [==============================] - 48s 523ms/step - loss: 2.9911e-04 - acc: 0.9999 - precision: 0.9999 - recall: 0.9999 - auc: 1.0000 - f1_m: 0.9999 - val_loss: 6.5769e-05 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 77/100
# 68/68 [==============================] - 48s 525ms/step - loss: 5.8917e-05 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 1.7977e-05 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 78/100
# 68/68 [==============================] - 48s 523ms/step - loss: 2.1309e-05 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 1.4741e-05 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 79/100
# 68/68 [==============================] - 48s 523ms/step - loss: 1.4628e-05 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 6.4466e-06 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 80/100
# 68/68 [==============================] - 48s 526ms/step - loss: 6.0361e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 6.4029e-06 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 81/100
# 68/68 [==============================] - 48s 523ms/step - loss: 7.7281e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 8.6776e-07 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 82/100
# 68/68 [==============================] - 48s 526ms/step - loss: 5.2467e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 2.2612e-06 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 83/100
# 68/68 [==============================] - 48s 523ms/step - loss: 3.4342e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 1.3051e-06 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 84/100
# 68/68 [==============================] - 48s 523ms/step - loss: 2.5838e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 1.8723e-06 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 85/100
# 68/68 [==============================] - 48s 523ms/step - loss: 3.9257e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 1.7113e-06 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 86/100
# 68/68 [==============================] - 48s 526ms/step - loss: 3.2298e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 9.9847e-07 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 87/100
# 68/68 [==============================] - 47s 520ms/step - loss: 3.5436e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 3.2979e-07 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 88/100
# 68/68 [==============================] - 48s 526ms/step - loss: 3.5235e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 1.7981e-06 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 89/100
# 68/68 [==============================] - 48s 526ms/step - loss: 2.1139e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 1.0824e-06 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 90/100
# 68/68 [==============================] - 48s 523ms/step - loss: 1.5258e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 8.1565e-07 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 91/100
# 68/68 [==============================] - 48s 526ms/step - loss: 2.2692e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 4.2849e-07 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 92/100
# 68/68 [==============================] - 48s 523ms/step - loss: 2.6268e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 9.6696e-07 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 93/100
# 68/68 [==============================] - 48s 526ms/step - loss: 1.2763e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 2.0438e-07 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 94/100
# 68/68 [==============================] - 48s 523ms/step - loss: 2.3376e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 4.3009e-07 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 95/100
# 68/68 [==============================] - 49s 532ms/step - loss: 1.1350e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 6.5704e-07 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 96/100
# 68/68 [==============================] - 48s 526ms/step - loss: 1.3215e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 2.9483e-07 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 97/100
# 68/68 [==============================] - 47s 520ms/step - loss: 7.7117e-07 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 1.4350e-07 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 98/100
# 68/68 [==============================] - 48s 529ms/step - loss: 1.4094e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 3.2650e-07 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 99/100
# 68/68 [==============================] - 48s 526ms/step - loss: 2.1930e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 6.1947e-07 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Epoch 100/100
# 68/68 [==============================] - 49s 535ms/step - loss: 1.3671e-06 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000 - val_loss: 1.4450e-07 - val_acc: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_m: 1.0000
# Training time: 01:21:04

# %%
#Plot loss and accuracy as a function of the epoch, for the training and validation datasets.
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
prec = history.history['precision']
rec = history.history['recall']
auc = history.history['auc']
val_prec = history.history['val_precision']
val_rec = history.history['val_recall']
val_auc = history.history['val_auc']

# Get number of epochs
epochs = range(len(acc))

# Plot training and validation accuracy per epoch
plt.plot(epochs, acc)
plt.plot(epochs, val_acc)
plt.title('Training and validation accuracy')
plt.legend(['acc', 'val_acc'], loc='upper left')
print("Training accuracy:", acc[-1])
print("Validation accuracy:", val_acc[-1])
    
# Plot training and validation loss per epoch
plt.figure()

plt.plot(epochs, loss)
plt.plot(epochs, val_loss)
plt.title('Training and validation loss')
plt.legend(['loss', 'val_loss'], loc='upper left')
print("\nTraining loss:", loss[-1])
print("Validation loss:", val_loss[-1])

plt.figure()
plt.plot(epochs, prec)
plt.plot(epochs, rec)
plt.plot(epochs, auc)
plt.title('Precision, Recall and AUC')
plt.legend(['precision', 'recall', 'auc'], loc='upper left')

plt.figure()
plt.plot(epochs, val_prec)
plt.plot(epochs, val_rec)
plt.plot(epochs, val_auc)
plt.title('Validation Precision, Recall and AUC')
plt.legend(['val_precision', 'val_recall', 'val_auc'], loc='upper left')
    
plt.show()
# Out:
# Training accuracy: 1.0
# Validation accuracy: 1.0
#
# Training loss: 1.3671117358171614e-06
# Validation loss: 1.4449848606545856e-07

# %%
results = model.evaluate(test_ds)
# Out:
# 11/11 [==============================] - 14s 92ms/step - loss: 2.1285e-07 - acc: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_m: 1.0000

# %%
predict_malware = test_ds.unbatch().filter(lambda x, y: y == 1).batch(128)

preds = model.predict(predict_malware)

correct_preds = preds > 0.5
wrong_preds = preds < 0.5
num_positive_preds = np.sum(correct_preds)
num_negative_preds = np.sum(wrong_preds)
print('Numero di previsioni corrette:', num_positive_preds)
print('Numero di previsioni errate:', num_negative_preds)
# Out:
# Numero di previsioni corrette: 4649
# Numero di previsioni errate: 4

# %%
predict_benign = test_ds.unbatch().filter(lambda x, y: y == 0).batch(128)

preds = model.predict(predict_benign)

correct_preds = preds < 0.5
wrong_preds = preds > 0.5
num_positive_preds = np.sum(correct_preds)
num_negative_preds = np.sum(wrong_preds)
print('Numero di previsioni corrette:', num_positive_preds)
print('Numero di previsioni errate:', num_negative_preds)
# Out:
# Numero di previsioni corrette: 142
# Numero di previsioni errate: 40
